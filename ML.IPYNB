# %%
# importing all necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv("CARS DATA.CSV")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df['Engine Fuel Type'].fillna("premium unleaded (required)",inplace=True)

# %%
df['Engine HP'].fillna(df['Engine HP'].median(),inplace=True)

# %%
df["Engine Cylinders"].fillna(df['Engine Cylinders'].median(),inplace=True)

# %%
df['Number of Doors'].fillna(2.0,inplace=True)

# %%
df.drop('Market Category',axis=1,inplace=True)

# %%
df['Year']=df['Year'].astype(str)

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                  object
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
ln=LabelEncoder()

# %%
df['Make_encode']=ln.fit_transform(df['Make'])

# %%
df['Engine Fuel Type_encode']=ln.fit_transform(df['Engine Fuel Type'])

# %%
df['Transmission Type_encode']=ln.fit_transform(df['Transmission Type'])

# %%
df['Driven_Wheels_encode']=ln.fit_transform(df['Driven_Wheels'])

# %%
df['Vehicle Size_encode']=ln.fit_transform(df['Vehicle Size'])

# %%
df['Vehicle Style_encode']=ln.fit_transform(df['Vehicle Style'])

# %%
df['Model_encode']=ln.fit_transform(df['Model'])

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\abdul malik\Downloads\CAR PRICE PREDICTION\ML.IPYNB Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/abdul%20malik/Downloads/CAR%20PRICE%20PREDICTION/ML.IPYNB#X62sZmlsZQ%3D%3D?line=0'>1</a> df.corr()
#
# File c:\Users\abdul malik\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\abdul malik\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
# ...

# %%
df[['Engine HP','Engine Cylinders','Number of Doors','highway MPG','city mpg','Popularity','MSRP','Make_encode','Engine Fuel Type_encode','Transmission Type_encode','Driven_Wheels_encode','Vehicle Size_encode','Vehicle Style_encode','Model_encode']].corr()
# Out:
#                           Engine HP  Engine Cylinders  Number of Doors  \
# Engine HP                  1.000000          0.767037        -0.103384
# Engine Cylinders           0.767037          1.000000        -0.137615
# Number of Doors           -0.103384         -0.137615         1.000000
# highway MPG               -0.359457         -0.600947         0.110819
# city mpg                  -0.353894         -0.565124         0.113032
# Popularity                 0.036823          0.040815        -0.048276
# MSRP                       0.661402          0.531139        -0.127521
# Make_encode               -0.226445         -0.263837         0.056081
# Engine Fuel Type_encode   -0.194705         -0.076755        -0.001178
# Transmission Type_encode  -0.238357         -0.164482        -0.335509
# Driven_Wheels_encode      -0.035007          0.087577        -0.252479
# Vehicle Size_encode        0.207912          0.195037         0.266882
# ...

# %%
x=df[['Engine HP','Engine Cylinders','Number of Doors','highway MPG','city mpg','Popularity','Make_encode','Engine Fuel Type_encode','Transmission Type_encode','Driven_Wheels_encode','Vehicle Size_encode','Vehicle Style_encode','Model_encode']]
y=df['MSRP']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2529)

# %%
lr=LinearRegression()

# %%
rf=RandomForestRegressor()

# %%
lr.fit(x_train,y_train)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
lr.score(x_train,y_train)
# Out:
# 0.48838147131603615

# %%
rf.score(x_train,y_train)
# Out:
# 0.9858309030354667

# %%
lr.score(x_test,y_test)
# Out:
# 0.46121906090881215

# %%
rf.score(x_test,y_test)
# Out:
# 0.9533000029235799

# %%
import pickle

# %%
# Save the model to a file using pickle
with open('model.pkl', 'wb') as model_file:
    pickle.dump(rf, model_file)

# %%
np.array(x_test.iloc[0])
# Out:
# array([250.,   5.,   4.,  29.,  20., 870.,  47.,   9.,   1.,   0.,   2.,
#         15., 838.])
